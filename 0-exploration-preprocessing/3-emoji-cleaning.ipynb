# %% [markdown]
# # Emoji Cleaning

# %% [markdown]
# | Author              | Description                                                                                                              |
# |---------------------|--------------------------------------------------------------------------------------------------------------------------|
# | Anh Tu Duong Nguyen | Here, we remove all emojis from the texts. Emojis are not usefule for our analysis and can be removed to clean the data. |

# %%
# %pip install textblob
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/cleaned_reviews_with_sentiment.csv")
df
# Out:
#          beer_id         username        date  \
# 0         271781     bluejacket74  2017-03-17
# 1         125646  GratefulBeerGuy  2017-12-20
# 2         125646         LukeGude  2017-12-20
# 3         125646             MFMB  2017-12-16
# 4         125646      jngrizzaffi  2017-12-10
# ...          ...              ...         ...
# 2987986    58482           smcolw  2009-08-22
# 2987987    58482    firkinhophead  2009-08-21
# 2987988    58482          CHADMC3  2009-08-21
# 2987989   104824     zookerman182  2014-06-24
# 2987990   104824        Hesscabob  2014-06-18
#
#                                                       text  look  smell  \
# 0           750 ml bottle, 2016 vintage, bottle #304 of...  4.00   4.00
# 1           0% 16 oz can. Funny story: As I finally wal...  4.75   4.75
# 2           Classic TH NEIPA. Overflowing head and bouq...  4.25   4.50
# 3           Pours a creamy opaque light straw yellow wi...  4.75   4.50
# ...

# %%
import emoji
def remove_emoji(text):
    return emoji.replace_emoji(text, replace='')

df["text"] = df["text"].apply(remove_emoji)
df
# Out:
#          beer_id         username        date  \
# 0         271781     bluejacket74  2017-03-17
# 1         125646  GratefulBeerGuy  2017-12-20
# 2         125646         LukeGude  2017-12-20
# 3         125646             MFMB  2017-12-16
# 4         125646      jngrizzaffi  2017-12-10
# ...          ...              ...         ...
# 2987986    58482           smcolw  2009-08-22
# 2987987    58482    firkinhophead  2009-08-21
# 2987988    58482          CHADMC3  2009-08-21
# 2987989   104824     zookerman182  2014-06-24
# 2987990   104824        Hesscabob  2014-06-18
#
#                                                       text  look  smell  \
# 0           750 ml bottle, 2016 vintage, bottle #304 of...  4.00   4.00
# 1           0% 16 oz can. Funny story: As I finally wal...  4.75   4.75
# 2           Classic TH NEIPA. Overflowing head and bouq...  4.25   4.50
# 3           Pours a creamy opaque light straw yellow wi...  4.75   4.50
# ...

# %%
df['text'] = df['text'].str.lstrip()

# %%
df
# Out:
#          beer_id         username        date  \
# 0         271781     bluejacket74  2017-03-17
# 1         125646  GratefulBeerGuy  2017-12-20
# 2         125646         LukeGude  2017-12-20
# 3         125646             MFMB  2017-12-16
# 4         125646      jngrizzaffi  2017-12-10
# ...          ...              ...         ...
# 2987986    58482           smcolw  2009-08-22
# 2987987    58482    firkinhophead  2009-08-21
# 2987988    58482          CHADMC3  2009-08-21
# 2987989   104824     zookerman182  2014-06-24
# 2987990   104824        Hesscabob  2014-06-18
#
#                                                       text  look  smell  \
# 0        750 ml bottle, 2016 vintage, bottle #304 of 36...  4.00   4.00
# 1        0% 16 oz can. Funny story: As I finally walked...  4.75   4.75
# 2        Classic TH NEIPA. Overflowing head and bouquet...  4.25   4.50
# 3        Pours a creamy opaque light straw yellow with ...  4.75   4.50
# ...

# %%
df.to_csv("../data/cleaned_reviews_without_emojis.csv", index=False)

# %% [markdown]
# # Results
# * A dataset contained of cleaned review text not contaning any emojis
#
# # Next Steps
# * TODO: Clarify which preprocessing steps are needed
